# %% [markdown]
# # 모든코인 상승장? 하락장?
# > 최고가와 최저가의 차이를 변동폭으로 정의할 때 (시가 + 변동폭)이 최고가 보다 높을 경우 "상승장", 그렇지 않은 경우 "하락장" 문자열을 출력하라.
#
#
# |Key Name|Description|
# |------|---|
# |opeing_price|최근 24시간 내 시작 거래금액|
# |closing_price|최근 24시간 내 마지막 거래금액|
# |min_price|최근 24시간 내 최저 거래금액|
# |max_price|최근 24시간 내 최고 거래금액|

# %%
import requests
url = "https://api.bithumb.com/public/ticker/all"
data = requests.get(url).json()['data']
for data_key,data_value in data.items():
    if data_key == 'date':
        continue
    a = float(data_value['max_price']) - float(data_value['min_price']) + float(data_value['opening_price'])
    print(type(a))
    if a > float(data_value['max_price']):
        print(f'{data_key}는 상승장')
    else:
        print(f'{data_key}는 하락장')
# Out:
# <class 'float'>
# BTC는 상승장
# <class 'float'>
# ETH는 하락장
# <class 'float'>
# DASH는 상승장
# <class 'float'>
# LTC는 상승장
# <class 'float'>
# ETC는 상승장
# <class 'float'>
# XRP는 상승장
# <class 'float'>
# BCH는 상승장
# <class 'float'>
# XMR는 상승장
# <class 'float'>
# ZEC는 상승장
# <class 'float'>
# QTUM는 상승장
# <class 'float'>
# BTG는 상승장
# <class 'float'>
# EOS는 상승장
# <class 'float'>
# ICX는 상승장
# <class 'float'>
# VET는 하락장
# <class 'float'>
# TRX는 상승장
# <class 'float'>
# ELF는 상승장
# <class 'float'>
# MITH는 상승장
# <class 'float'>
# MCO는 상승장
# <class 'float'>
# OMG는 상승장
# <class 'float'>
# KNC는 상승장
# <class 'float'>
# GNT는 상승장
# <class 'float'>
# ZIL는 상승장
# <class 'float'>
# ETHOS는 상승장
# <class 'float'>
# PAY는 하락장
# <class 'float'>
# WAX는 상승장
# <class 'float'>
# POWR는 상승장
# <class 'float'>
# LRC는 상승장
# <class 'float'>
# GTO는 상승장
# <class 'float'>
# STEEM는 상승장
# <class 'float'>
# STRAT는 상승장
# <class 'float'>
# ZRX는 상승장
# <class 'float'>
# REP는 상승장
# <class 'float'>
# AE는 상승장
# <class 'float'>
# XEM는 하락장
# ...

# %% [markdown]
# # 평균점수
# > 다음 딕셔너리에서 평균 점수를 출력하라

# %%
student = {'python':80, 'algorithm':78, 'django':95, 'flask':80}
student_result = 0
for student_value in student.values():
    student_result += student_value
    
print(student_result / len(student))
# Out:
# 83.25

# %% [markdown]
# # 혈액형
# > 학생들의 혈액형(A,B,O,AB)에 대한 데이터가 리스트에 들어있다. 각 혈액형이 몇명인지 딕셔너리를 만들어 출력하라

# %%
blood = ['A','A','B','O','A','B','A','AB','AB','O','A','O','AB','O']
# a_cnt = 0
# b_cnt = 0
# o_cnt = 0
# ab_cnt = 0
# for cnt in blood:
#     if cnt == 'A':
#         a_cnt += 1
#     elif cnt == 'B':
#         b_cnt += 1
#     elif cnt == 'O':
#         o_cnt += 1
#     else:
#         ab_cnt += 1
# print(a_cnt)
# print(b_cnt)
# print(o_cnt)
# print(ab_cnt)
blood_dict = {}
for b in blood:
    if b in blood_dict:
        blood_dict[b] += 1
    else:
        blood_dict[b] = 1
print(blood_dict)
# Out:
# {'A': 5, 'B': 2, 'O': 4, 'AB': 3}

# %% [markdown]
# # UBD
# > movies는 영화제목이 key로 누적관객수가 value인 딕셔너리이다.
# >
# > 자전차왕 엄복동의 누적관객수는 172212명이고 172212명을 1UBD라고 할때 80UBD를 넘지 못하는 영화를 출력하라.

# %%
movies = {
    "7번방의선물":12811206,
    "괴물":13019740,
    "국제시장":14257115,
    "극한직업":16261018,
    "도둑들":12983330,
    "명량":17613682,
    "베테랑":13414009,
    "신과함께-죄와벌":14410754,
    "아바타":13624328,
    "어벤져스:엔드게임":13901423,
}
ubd = 172212 * 80
for a,b in movies.items():
    if b < ubd:
        print(a)
    else:
        pass
# Out:
# 7번방의선물
# 괴물
# 도둑들
# 베테랑
# 아바타
